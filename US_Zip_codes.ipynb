# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("zipCode_48.csv")

# %%
df.head()
# Out:
#    Zipcode ZipCodeType         City State LocationType    Lat    Long  \
# 0    98357      PO BOX     NEAH BAY    WA      PRIMARY  48.33 -124.63
# 1    98350      PO BOX      LA PUSH    WA      PRIMARY  47.90 -124.61
# 2    98326    STANDARD  CLALLAM BAY    WA      PRIMARY  48.17 -124.53
# 3    97464      PO BOX        OPHIR    OR      PRIMARY  42.50 -124.41
# 4    97491      PO BOX   WEDDERBURN    OR      PRIMARY  42.45 -124.40
#
#                Location  Decommisioned  TaxReturnsFiled  EstimatedPopulation  \
# 0     NA-US-WA-NEAH BAY          False            473.0                877.0
# 1      NA-US-WA-LA PUSH          False              NaN                  NaN
# 2  NA-US-WA-CLALLAM BAY          False              NaN                  NaN
# 3        NA-US-OR-OPHIR          False              NaN                  NaN
# 4   NA-US-OR-WEDDERBURN          False              NaN                  NaN
#
#    TotalWages
# 0  12642512.0
# 1         NaN
# 2         NaN
# 3         NaN
# ...

# %%
df.isnull().sum()
# Out:
# Zipcode                    0
# ZipCodeType                0
# City                       0
# State                      0
# LocationType               0
# Lat                        0
# Long                       0
# Location                   0
# Decommisioned              0
# TaxReturnsFiled        12043
# EstimatedPopulation    12043
# TotalWages             12078
# dtype: int64

# %%
df.drop(columns = ['TaxReturnsFiled','EstimatedPopulation','TotalWages'])
# Out:
#        Zipcode ZipCodeType         City State LocationType    Lat    Long  \
# 0        98357      PO BOX     NEAH BAY    WA      PRIMARY  48.33 -124.63
# 1        98350      PO BOX      LA PUSH    WA      PRIMARY  47.90 -124.61
# 2        98326    STANDARD  CLALLAM BAY    WA      PRIMARY  48.17 -124.53
# 3        97464      PO BOX        OPHIR    OR      PRIMARY  42.50 -124.41
# 4        97491      PO BOX   WEDDERBURN    OR      PRIMARY  42.45 -124.40
# ...        ...         ...          ...   ...          ...    ...     ...
# 40704     4666    STANDARD     PEMBROKE    ME      PRIMARY  44.95  -67.16
# 40705     4671    STANDARD   ROBBINSTON    ME      PRIMARY  45.06  -67.16
# 40706     4652    STANDARD        LUBEC    ME      PRIMARY  44.79  -67.11
# 40707     4667    STANDARD        PERRY    ME      PRIMARY  44.97  -67.07
# 40708     4631    STANDARD     EASTPORT    ME      PRIMARY  44.91  -67.01
#
#                    Location  Decommisioned
# ...

# %%
df.plot(x="Long", y="Lat", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Long', ylabel='Lat'>
